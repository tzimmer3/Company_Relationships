# %%
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

credential = DefaultAzureCredential()
client = SecretClient(vault_url="https://scienceenginea4747056219.vault.azure.net/", credential=credential)
# aoai_endpoint = client.get_secret("OpenAIAPIEndpointSCUS").value
# aoai_secret = client.get_secret("OpenAIAPIKeySCUS").value
aoai_endpoint = client.get_secret("OpenAIAPIEndpointEUS").value
aoai_secret = client.get_secret("OpenAIAPIKeyEUS").value
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from azure.identity import DefaultAzureCredential
# ----> 2 from azure.keyvault.secrets import SecretClient
#       4 credential = DefaultAzureCredential()
#       5 client = SecretClient(vault_url="https://scienceenginea4747056219.vault.azure.net/", credential=credential)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\__init__.py:5
#       1 # ------------------------------------
#       2 # Copyright (c) Microsoft Corporation.
#       3 # Licensed under the MIT License.
#       4 # ------------------------------------
# ----> 5 from ._models import DeletedSecret, KeyVaultSecret, KeyVaultSecretIdentifier, SecretProperties
#       6 from ._shared.client_base import ApiVersion
#       7 from ._client import SecretClient
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\_models.py:5
#       1 # ------------------------------------
#       2 # Copyright (c) Microsoft Corporation.
#       3 # Licensed under the MIT License.
#       4 # ------------------------------------
# ----> 5 from ._shared import parse_key_vault_id
#       7 try:
#       8     from typing import TYPE_CHECKING
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\_shared\__init__.py:13
#      11 from typing import TYPE_CHECKING
#      12 from .challenge_auth_policy import ChallengeAuthPolicy
# ---> 13 from .client_base import KeyVaultClientBase
#      14 from .http_challenge import HttpChallenge
#      15 from . import http_challenge_cache
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\_shared\client_base.py:15
#      12 from azure.core.pipeline.policies import HttpLoggingPolicy
#      14 from . import ChallengeAuthPolicy
# ---> 15 from .._generated import KeyVaultClient as _KeyVaultClient
#      16 from .._sdk_moniker import SDK_MONIKER
#      18 if TYPE_CHECKING:
#      19     # pylint:disable=unused-import,ungrouped-imports
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\_generated\__init__.py:9
#       1 # coding=utf-8
#       2 # --------------------------------------------------------------------------
#       3 # Copyright (c) Microsoft Corporation. All rights reserved.
#    (...)
#       6 # Changes may cause incorrect behavior and will be lost if the code is regenerated.
#       7 # --------------------------------------------------------------------------
# ----> 9 from ._key_vault_client import KeyVaultClient
#      10 __all__ = ['KeyVaultClient']
#      12 try:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\azure\keyvault\secrets\_generated\_key_vault_client.py:17
#      14 from msrest import Deserializer, Serializer
#      16 from azure.core import PipelineClient
# ---> 17 from azure.profiles import KnownProfiles, ProfileDefinition
#      18 from azure.profiles.multiapiclient import MultiApiClientMixin
#      20 from ._configuration import KeyVaultClientConfiguration
#
# ModuleNotFoundError: No module named 'azure.profiles'

# %%
import json
import os
import time
from typing import List
from wasabi import msg
from time import sleep

import numpy as np
import requests
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup
import openai
import gzip
from transformers import GPT2TokenizerFast
from urllib.request import Request

# API keys and endpoints
BING_API_KEY = os.environ["BING_SEARCH_V7_SUBSCRIPTION_KEY"]
BING_ENDPOINT = "https://api.bing.microsoft.com/v7.0/news/search"
# openai api from azure
openai.api_type = "azure"
openai.api_base = aoai_endpoint
openai.api_version = "2022-12-01"
openai.api_key = aoai_secret
TOKENIZER = GPT2TokenizerFast.from_pretrained("gpt2")
ALLOWED_TEXT_TOKEN_LENGTH = 2500
GENERATION_TOKEN_LENGTH = 4096 - ALLOWED_TEXT_TOKEN_LENGTH

PROMPTS = {
    "topics": "Main news topic in a list: ", 
    "sentiment": "From this article, the overall sentiment is: ", 
    "entities": "Find the entities in a list: ", 
    "regulations": "From this article, is there any new rules or changes in regulations in a list: "
    }

FEW_SHOT_PROMPT_FOR_RELATIONS = {
    "demonstration": 
        """text: There is still some uncertainty that Musk - 
        also chief executive of electric car maker Tesla and rocket company SpaceX - 
        will pull off his planned buyout. \n relations: Tesla, Musk, top_members/employees; 
        Musk, Tesla, employee_of; Musk, SpaceX, employee_of; SpaceX, Musk, top_members/employees \n text: """,
    "prompt": "relations: "}

def encode_and_decode_text(text):
    encoded_text = TOKENIZER.encode(
        text=text,
        max_length=ALLOWED_TEXT_TOKEN_LENGTH,
        truncation=True,
        add_special_tokens=True,
        padding=False,
    )
    return TOKENIZER.decode(encoded_text, skip_special_tokens=False)
    
def query_bing_news(query: str, freshness: str) -> dict:
    # Construct a request
    mkt = "en-US"
    params = {"q": query, "mkt": mkt, "count": 100, "freshness": freshness}
    headers = {"Ocp-Apim-Subscription-Key": BING_API_KEY}
    
    # freshness has to be one of the 3 defined keys
    # if not, we use Week instead
    if freshness not in ["Month", "Week", "Day"]:
        raise UserWarning(f"Key 'freshness' is expected to be one of[Month, Week, Day], got '{freshness}' instead.")

    # Call the API
    try:
        response = requests.get(BING_ENDPOINT, headers=headers, params=params)
        response.raise_for_status()
        return response.json()
    except Exception as ex:
        raise ex
    
def count_words(input_string):
    words = input_string.split()
    return len(words)

def select_first_n_words(input_string, top_n_words=3500):
    words = input_string.split()
    return " ".join(words[:top_n_words])

def extract_main_text_from_webpage(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    res = urlopen(req)
    content = res.read()
    # check if the site is using gzip for compression
    if res.headers["Content-Encoding"] == "gzip":
        content = gzip.decompress(content)
        
    soup = BeautifulSoup(content, features="html.parser", from_encoding="iso-8859-1")
    # print(soup)
    # remove all script and style elements
    [s.extract() for s in soup(["script", "style"])]

    # get text and join all chunks into a single string
    text = ' '.join(soup.stripped_strings)

    return text

def query_openai_api(text, prompt):
    response = openai.Completion.create(
        engine="aiarch-text-davinci-003",
        # engine="aiarch-text-davinci-002",
        prompt=f"{prompt} \n {encode_and_decode_text(text)} \n",
        temperature=0.9,
        max_tokens=GENERATION_TOKEN_LENGTH - len(TOKENIZER.encode(text=prompt,max_length=None,truncation=True,add_special_tokens=True,padding=False)) - 1,
        top_p=0.5,
        frequency_penalty=0,
        presence_penalty=0,
        best_of=1,
        stop=None)
    text = "\n".join([item for item in response["choices"][0]["text"].split("\n") if item != ""])
    return text

def query_openai_api_with_demonstration(text, prompt, demonstration):
    response = openai.Completion.create(
        engine="aiarch-text-davinci-003",
        # engine="aiarch-text-davinci-002",
        prompt=f"{demonstration} {encode_and_decode_text(text)} \n {prompt}",
        temperature=0.9,
        max_tokens=GENERATION_TOKEN_LENGTH - len(TOKENIZER.encode(text=f"{demonstration} {encode_and_decode_text(text)} \n {prompt}",max_length=None,truncation=True,add_special_tokens=True,padding=False)) - 1,
        top_p=0.5,
        frequency_penalty=0,
        presence_penalty=0,
        best_of=1,
        stop=None)
    return response["choices"][0]["text"]

# %%
res = query_openai_api_with_demonstration("Biden wants to drive down drug costs. Price controls won't work.", 
                                    FEW_SHOT_PROMPT_FOR_RELATIONS["prompt"], 
                                    FEW_SHOT_PROMPT_FOR_RELATIONS["demonstration"])
res
# Out:
# " Biden, drug costs, wants_to_lower; drug costs, price controls, won't_work"

# %%
def news_intelligence(topic: str, freshness: str, top_n=10):
    news = query_bing_news(topic, freshness=freshness)["value"][:top_n]
    msg.good(f"Found {len(news)} news articles for topic '{topic}'")
    # print(news)
    for i in range(len(news)):
        record = news[i]
        msg.info(f"Processing article {i+1}/{len(news)}")
        # print(record["url"])
        extracted_text = extract_main_text_from_webpage(record["url"])
        msg.info(f"Extracted text: {extracted_text[:20]}...")
        msg.info(f"Extracted {count_words(extracted_text)} words from article {i+1}/{len(news)}")
        # print(count_words(extracted_text))
        # print("extracted_text", extracted_text)
        for key, prompt in PROMPTS.items():
            msg.info(f"Querying OpenAI for '{key}'")
            try:
                record[key] = query_openai_api(extracted_text, prompt)
            except Exception as e:
                msg.fail(f"Error querying OpenAI for '{key}': {e}")
                record[key] = None
        # query the few shot example
        try:
            msg.info(f"Querying OpenAI for 'extracted_relations'")
            record["extracted_relations"] = query_openai_api_with_demonstration(extracted_text, 
                                                                                FEW_SHOT_PROMPT_FOR_RELATIONS["prompt"], 
                                                                                FEW_SHOT_PROMPT_FOR_RELATIONS["demonstration"])
        except Exception as e:
            msg.fail(f"Error querying OpenAI for 'extracted_relations': {e}")
            record["extracted_relations"] = None
        msg.good(f"Querying OpenAI successful")
    return news

# %%
# extract_main_text_from_webpage("https://firstwordpharma.com/story/5708013")

# %%
NEWS_QUERY = "pharma companies"

# %%
res = news_intelligence(NEWS_QUERY, freshness="Week", top_n=10)
# Out:
# ✔ Found 10 news articles for topic 'pharma companies'
# ℹ Processing article 1/10
# ℹ Extracted text: Biden wants to drive...
# ℹ Extracted 1109 words from article 1/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 2/10
# ℹ Extracted text: Executive chairman o...
# ℹ Extracted 272 words from article 2/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 3/10
# ℹ Extracted text: Lexington County pha...
# ℹ Extracted 1755 words from article 3/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 4/10
# ℹ Extracted text: Sanders targets phar...
# ℹ Extracted 1272 words from article 4/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 5/10
# ℹ Extracted text: Sales incentives wor...
# ℹ Extracted 1239 words from article 5/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 6/10
# ℹ Extracted text: Pharma Regulatory Ma...
# ℹ Extracted 3323 words from article 6/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 7/10
# ℹ Extracted text: Pharmaceutical Equip...
# ℹ Extracted 2262 words from article 7/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 8/10
# ℹ Extracted text: Kobach goes after CV...
# ℹ Extracted 1445 words from article 8/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 9/10
# ℹ Extracted text: Analysts Offer Insig...
# ℹ Extracted 907 words from article 9/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful
# ℹ Processing article 10/10
# ℹ Extracted text: Pharmaceutical Compa...
# ℹ Extracted 2475 words from article 10/10
# ℹ Querying OpenAI for 'topics'
# ℹ Querying OpenAI for 'sentiment'
# ℹ Querying OpenAI for 'entities'
# ℹ Querying OpenAI for 'regulations'
# ℹ Querying OpenAI for 'extracted_relations'
# ✔ Querying OpenAI successful

# %%
df_res = pd.DataFrame(res)
df_res
# Out:
#                                                 name  \
# 0  $130,000 for medicine is outrageous. Blame the...
# 1  Executive chairman of Spanish pharma company G...
# 2  Lexington County pharmaceutical company furlou...
# 3  Sanders targets pharma companies over vaccine ...
# 4  Sales incentives worth ₹165.74 crore released ...
# 5  Pharma Regulatory Management Systems Market Si...
# 6  Pharmaceutical Equipment Market 2023: A Status...
# 7  Kobach goes after second pharmaceutical compan...
# 8  Analysts Offer Insights on Healthcare Companie...
# 9  Pharmaceutical Company's Expansion to Frederic...
#
#                                                  url  \
# 0  https://www.usatoday.com/story/opinion/columni...
# 1  https://www.msn.com/en-gb/health/other/executi...
# 2  https://www.postandcourier.com/columbia/busine...
# 3  https://www.msn.com/en-us/news/other/sanders-t...
# 4  https://www.thehindu.com/business/sales-incent...
# 5  https://www.marketwatch.com/press-release/phar...
# 6  https://www.marketwatch.com/press-release/phar...
# 7  https://fox4kc.com/news/kobach-goes-after-seco...
# 8  https://markets.businessinsider.com/news/stock...
# 9  https://www.westword.com/news/agilent-expansio...
#
#                                                image  \
# 0  {'thumbnail': {'contentUrl': 'https://www.bing...
# 1  {'thumbnail': {'contentUrl': 'https://www.bing...
# 2  {'thumbnail': {'contentUrl': 'https://www.bing...
# 3  {'thumbnail': {'contentUrl': 'https://www.bing...
# 4  {'thumbnail': {'contentUrl': 'https://www.bing...
# 5                                                NaN
# 6                                                NaN
# 7  {'thumbnail': {'contentUrl': 'https://www.bing...
# 8                                                NaN
# 9  {'thumbnail': {'contentUrl': 'https://www.bing...
#
#                                          description  \
# 0  A lot of people, including President Joe Biden...
# 1  MADRID (Reuters) - Steven F. Mayer has resigne...
# 2  A March 2022 inspection found issues with how ...
# 3  Vermont Sen. Bernie Sanders took aim at pharma...
# 4  Four pharmaceutical companies have received th...
# 5  Pharma Regulatory Management Systems Market 20...
# 6  Feb 21, 2023 (The Expresswire) -- "Final Repor...
# 7  Following a “significant victory for the pro-l...
# 8  There’s a lot to be optimistic about in the He...
# 9  Agilent Technologies chose Frederick, Colorado...
#
#                                                about  \
# 0  [{'readLink': 'https://api.bing.microsoft.com/...
# 1  [{'readLink': 'https://api.bing.microsoft.com/...
# 2  [{'readLink': 'https://api.bing.microsoft.com/...
# 3                                                NaN
# 4  [{'readLink': 'https://api.bing.microsoft.com/...
# 5                                                NaN
# 6  [{'readLink': 'https://api.bing.microsoft.com/...
# 7  [{'readLink': 'https://api.bing.microsoft.com/...
# 8                                                NaN
# 9  [{'readLink': 'https://api.bing.microsoft.com/...
#
#                                             provider  \
# 0  [{'_type': 'Organization', 'name': 'YAHOO!News...
# 1         [{'_type': 'Organization', 'name': 'MSN'}]
# 2  [{'_type': 'Organization', 'name': 'Post and C...
# 3         [{'_type': 'Organization', 'name': 'MSN'}]
# 4   [{'_type': 'Organization', 'name': 'The Hindu'}]
# 5  [{'_type': 'Organization', 'name': 'MarketWatc...
# 6  [{'_type': 'Organization', 'name': 'MarketWatc...
# 7  [{'_type': 'Organization', 'name': 'WDAF-TV', ...
# 8  [{'_type': 'Organization', 'name': 'Business I...
# 9  [{'_type': 'Organization', 'name': 'Westword',...
#
#                   datePublished  \
# 0  2023-02-21T11:00:00.0000000Z
# 1  2023-02-21T17:15:00.0000000Z
# 2  2023-02-20T23:10:00.0000000Z
# 3  2023-02-19T16:12:00.0000000Z
# 4  2023-02-22T00:47:00.0000000Z
# 5  2023-02-20T23:30:00.0000000Z
# 6  2023-02-21T08:24:00.0000000Z
# 7  2023-02-21T21:26:00.0000000Z
# 8  2023-02-21T16:30:00.0000000Z
# 9  2023-02-20T12:00:00.0000000Z
#
#                                                video              category  \
# 0  {'name': 'Pfizer, French partner Valneva begin...                Health
# 1                                                NaN              Business
# 2                                                NaN              Business
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN              Business
# 7                                                NaN                Health
# 8                                                NaN  ScienceAndTechnology
# 9                                                NaN              Business
#
#                                               topics  \
# 0  1. Biden wants to drive down drug costs\n2. Pr...
# 1  1. Executive chairman of Spanish pharma compan...
# 2  1. Lexington County pharmaceutical company fur...
# 3  1. Sanders targets pharma companies over vacci...
# 4  1. Sales incentives worth â¹165.74 crore rele...
# 5  1. Main news topic: Pharma Regulatory Manageme...
# 6  Main News Topic in a List:\n1. Overview of the...
# 7  1. Attorney General Kris Kobach puts pressure ...
# 8  1. Analysts Offer Insights on Healthcare Compa...
# 9  Main News Topic:\n1. Pharmaceutical Company's ...
#
#                                            sentiment  \
# 0  The overall sentiment of this article is that ...
# 1  The overall sentiment of this article is neutral.
# 2  The overall sentiment of this article is negat...
# 3  The overall sentiment is one of criticism of p...
# 4  The overall sentiment is positive, as the arti...
# 5  The overall sentiment of this article is posit...
# 6  The overall sentiment of this article is posit...
# 7  The overall sentiment of this article is that ...
# 8  The overall sentiment is optimistic, as analys...
# 9  The overall sentiment of this article is posit...
#
#                                             entities  \
# 0  Biden, Price Controls, Come Meet Us, Time to L...
# 1  Entities: \n1. Steven F. Mayer \n2. Thomas Gla...
# 2  1. Lexington County pharmaceutical company \n2...
# 3  Entities: \nSanders, Moderna, Stéphane Bancel,...
# 4  Entities: \n-Dr. Reddy’s Laboratories Limited ...
# 5  Entities: \n- EXTEDO \n- NNIT \n- Instem (Sama...
# 6  Entities: \nGE Healthcare, Siemens, Bosch, Sar...
# 7  Entities: \nKobach, CVS, Walgreens, Kansas, At...
# 8  Entities: Ligand Pharma (LGND), Seagen (SGEN),...
# 9  Entities: \nAgilent Technologies, Colorado Off...
#
#                                          regulations  \
# 0  No, there are no new rules or changes in regul...
# 1  No, there are no new rules or changes in regul...
# 2  No, there are no new rules or changes in regul...
# 3  No, there are no new rules or changes in regul...
# 4  No, there are no new rules or changes in regul...
# 5  No, there are no new rules or changes in regul...
# 6  No, there are no new rules or changes in regul...
# 7  No, there are no new rules or changes in regul...
# 8  No, there are no new rules or changes in regul...
# 9  No, there are no new rules or changes in regul...
#
#                                  extracted_relations
# 0   Biden, drug_costs, wants_to_lower; Biden, pri...
# 1   Grifols, Steven F. Mayer, top_members/employe...
# 2  \nNephron Pharmaceuticals Corporation, employe...
# 3   Sanders, Moderna, calls_for_testimony; \n    ...
# 4   Department for Pharmaceuticals, four pharma c...
# 5  \n Pharma Regulatory Management Systems Market...
# 6   Pharmaceutical Equipment, GE Healthcare, manu...
# 7  \n Kobach, Walgreens, warned; Walgreens, Kobac...
# 8   Ligand Pharma, Benchmark Co., analyst; Seagen...
# 9   Agilent Technologies, Brian Carothers, employ...

# %%
df_res.to_csv(f"res_{NEWS_QUERY.replace(' ', '_')}.csv", index=False)

# %%
df_res["topics"].values.tolist()[0].split("\n")
# Out:
# ['1. Biden wants to drive down drug costs',
#  "2. Price controls won't work",
#  '3. Pharmaceutical industry blamed for high drug costs',
#  '4. FDA regulations drive up costs',
#  '5. Hatch-Waxman Act allows drugmakers to maintain monopoly',
#  '6. Medicare and Medicaid share blame for high prices',
#  '7. Price controls discourage research and development',
#  '8. Price controls have unintended consequences',
#  '9. Price controls are popular but not effective',
#  '10. Government intervention into free market not the answer']

# %%
df_res["extracted_relations"].values.tolist()[0].split("\n")
# Out:
# [' Biden, drug_costs, wants_to_lower; Biden, price_controls, does_not_support; FDA, drug_costs, increases; FDA, generic_drugs, approval_process; Hatch-Waxman_Act, drug_costs, increases; Medicare, drug_costs, increases; Medicaid, drug_costs, increases; Pharmaceutical_Industry, drug_costs, increases; government, drug_costs, increases; Johnson_&_Johnson, Prezista, 167_protections; Gilead, Truvada, 120_protections; Gilead, Viread, 118_protections; Biden, price_controls, supports; market, drug_costs, balances_supply_and_demand; Venezuela, price_controls, failure; India, price_controls, failure; US, pharmaceutical_innovation, leads; Canada, pharmaceutical_innovation, low_rank; health_care_industry, regulations, most_regulated; television_set_industry, regulations, not_overburdened; Biden, price_controls, popularity; market, investments, encourages; market, product_quality, inferior; market, illegal_markets, encourages; market, shortages, encourages; market, rationing, encourages; market, innovation, discourages; market, research_and_development, discourages.']

# %%
df_res["entities"].values.tolist()[0].split("\n")
# Out:
# ['Biden, Price Controls, Come Meet Us, Time to Legalize Weed?, U.S., Sports, Entertainment, Life, Money, Tech, Travel, Opinion, ONLY AT USA TODAY, Newsletters, For Subscribers, From the Archives, Support Local, Crossword, eNewspaper, Magazines, Investigations, Weather Forecast, Podcasts, Video, Humankind, Just Curious, Pet Health, Reviewed, Coupons, Pharmaceutical Industry, $130,000, medicine, government, pharmaceutical companies, President Biden, free market, FDA, Food and Drug Administration, generic drugs, Hatch-Waxman Act, patent, intellectual property, Chris Schlak, USA TODAY, family, multiple sclerosis, prescriptions, MS LifeLines, charity, Rebif, United States, corporate greed, State of the Union address, government intervention, tariffs, Johnson & Johnson, Janssen Global HIV, Center for Innovation, University of California College of the Law, San Francisco, Gilead, Truvada, Viread, Medicare, Medicaid, monopoly, pill coating, evergreening, Bureaucrats, pain, patients, Richard Owens, Macdonald-Laurier Institute, 56 countries, Canada, Peter G. Peterson Foundation, 2009, television set industry, Official Data Foundation, U.S. Bureau of Labor Statistics, health care industry, regulated industries, America, Richard Owens, Ottawa-based Macdonald-Laurier Institute, 27th, innovation, investments, research and development, price controls, Venezuela, India, shortages, rationing, inferior product quality, illegal markets, supply and demand, producers, consumers, monopoly control, Chris Schlak, Opinion fellow, USA TODAY, University of Texas at Austin, The Texas Horn, Intercollegiate Studies Institute, Twitter, Featured Weekly Ad, About Us, Newsroom Staff, Ethical Principles, Request a Correction, Press Releases, Accessibility, Sitemap, Terms of Service, Your California Privacy Rights/Privacy Policy, Privacy Policy, Do Not Sell My Info/Cookie Policy, Contact Us, Help Center, My Account, Give Feedback, Get Home Delivery, eNewspaper, USA TODAY Shop, USA TODAY Print Editions, Licensing & Reprints, Advertise, Careers, Internships, Support Local Business, News Tips, Submitting letters to the editor, Podcasts, Newsletters, Mobile Apps, Facebook, Twitter, Instagram, LinkedIn, Pinterest, YouTube, Reddit, Flipboard, RSS, 10Best, Reviewed Jobs, Sports Weekly, Studio Gannett, USA TODAY Sports+, Classifieds, Coupons']

# %%
def graph_aggregation(graphs):
    res = query_openai_api("\n".join([g for g in graphs]), prompt="extract the relations from this:")
    return res

# %%
# graph_str = graph_aggregation(df_res["extracted_relations"])

# %%
# graph_str.split("\n")
