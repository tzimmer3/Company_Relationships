# %% [markdown]
# # Semantic Search on a Corpus

# %%
# Import Packages
import json
import numpy as np
import pandas as pd
import tiktoken
from joblib import load

# %% [markdown]
# ## Import Data

# %%
# Import Data
filepath = "C:\\Users\\hlmq\\OneDrive - Chevron\\Desktop\\Projects\\Company Relationships\\Data\\Exxon\\"
filename = "CompanyProfileNewsData_withEmbeddings.json"

df = pd.read_json(str(filepath)+str(filename))
len(df)
# Out:
# 1331

# %%
df['n_link'] = df['n_link'].astype(str)

# %%
# ================== #
# Tokenize Text
# ================== #

# TODO: change tiktoken out to real tokenizer... or use tiktoken

def get_tokens(text_2_encode: str, tokenizer=None):
    """
    Tokenize text in a string.

    Initialize a tokenizer if tokenizer == None.
    """

    if tokenizer is None:
        tokenizer = tiktoken.encoding_for_model("text-davinci-003")
    return tokenizer.encode(text=text_2_encode)


def get_num_tokens(text_2_encode: str, **kwargs):
    """
    Count the number of tokens in a string.
    """
    return len(get_tokens(text_2_encode=text_2_encode, **kwargs))


# ================== #
#  Get Embeddings
# ================== #

def get_embeddings(text=None, model=None):
    """
    Generate embeddings on a string of text.
    """
    if model==None:
        model = load('./model/SentBERTmodel.pkl')

    return model.encode(text)


# ================== #
#  Calculate Vector Similarity
# ================== #

def vector_similarity(x: "list[float]", y: "list[float]") -> float:
    """
    Returns the similarity between two vectors.

    Because embeddings are normalized to length 1, the cosine similarity is the same as the dot product.
    """
    return np.dot(np.array(x), np.array(y))


# ================== #
#  Order Chunks by Similarity
# ================== #

def measure_embedding_similarity(
    query: str,
    embeddings
):
    """
    Find the query embedding for the supplied query, and compare it against all of the pre-calculated document embeddings
    to find the most relevant sections.

    Return the list of document sections, sorted by relevance in descending order.
    """
    query_embedding = get_embeddings(query)

    return [vector_similarity(query_embedding, embedding) for embedding in embeddings]


# ================== #
#  Get Similar Texts
# ================== #

def get_similar_texts(df, k):
    """
    Slice a dataframe on the top k results.  Sort the sliced dataframe descending on similarity score.

    If there are repeated results in top 5, keep them all.
    """
    response = df.nlargest(k, columns=['similarity score'],keep='all')
    response = response.sort_values(by='similarity score', ascending=False)
    return response

# %%
# ================== #
#  Run (score.py)
# ================== #

def run(question: str, k: int, embeddings, df) -> dict[str,str]:

    # Retrieve Top K Most Similar Results
    df['similarity score'] = measure_embedding_similarity(question, embeddings)

    # Count number of tokens in each article
    df['token count'] = df['n_summary'].apply(get_num_tokens)
    
    # Return Chunks With Highest Similarity (Text)
    response = get_similar_texts(df, k)

    # Remove embeddings column
    keep_columns = ['n_title', 'n_link', 'n_date_published', 'n_summary', 'token count', 'similarity score']
    response = response[keep_columns]
    
    return response

# %%
# Produce Data

# Generate embeddings
#embeddings = get_embeddings(df['n_summary'])
#df['embeddings'] = embeddings.tolist()

# %% [markdown]
# ## Ask Questions

# %%
response = run("is ExxonMobil investing in advanced recycling of plastic", 5, df['embeddings'], df)

response.style.set_properties(subset=['n_summary'], **{'width': '900px'})
# Out:
# <style type="text/css">
# #T_0a39b_row0_col3, #T_0a39b_row1_col3, #T_0a39b_row2_col3, #T_0a39b_row3_col3, #T_0a39b_row4_col3 {
#   width: 900px;
# }
# </style>
# <table id="T_0a39b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a39b_level0_col0" class="col_heading level0 col0" >n_title</th>
#       <th id="T_0a39b_level0_col1" class="col_heading level0 col1" >n_link</th>
#       <th id="T_0a39b_level0_col2" class="col_heading level0 col2" >n_date_published</th>
#       <th id="T_0a39b_level0_col3" class="col_heading level0 col3" >n_summary</th>
#       <th id="T_0a39b_level0_col4" class="col_heading level0 col4" >token count</th>
#       <th id="T_0a39b_level0_col5" class="col_heading level0 col5" >similarity score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a39b_level0_row0" class="row_heading level0 row0" >404</th>
# ...

# %%
response = run("What are Exxon's decarbonization goals?", 5, df['embeddings'], df)

response.style.set_properties(subset=['n_summary'], **{'width': '900px'})
# Out:
# <style type="text/css">
# #T_22bf0_row0_col3, #T_22bf0_row1_col3, #T_22bf0_row2_col3, #T_22bf0_row3_col3, #T_22bf0_row4_col3 {
#   width: 900px;
# }
# </style>
# <table id="T_22bf0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22bf0_level0_col0" class="col_heading level0 col0" >n_title</th>
#       <th id="T_22bf0_level0_col1" class="col_heading level0 col1" >n_link</th>
#       <th id="T_22bf0_level0_col2" class="col_heading level0 col2" >n_date_published</th>
#       <th id="T_22bf0_level0_col3" class="col_heading level0 col3" >n_summary</th>
#       <th id="T_22bf0_level0_col4" class="col_heading level0 col4" >token count</th>
#       <th id="T_22bf0_level0_col5" class="col_heading level0 col5" >similarity score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22bf0_level0_row0" class="row_heading level0 row0" >264</th>
# ...

# %%
response = run("How much is Exxon planning to invest in Carbon Capture, Utilization, and Storage?", 5, df['embeddings'], df)

response.style.set_properties(subset=['n_summary'], **{'width': '900px'})
# Out:
# <style type="text/css">
# #T_d551b_row0_col3, #T_d551b_row1_col3, #T_d551b_row2_col3, #T_d551b_row3_col3, #T_d551b_row4_col3 {
#   width: 900px;
# }
# </style>
# <table id="T_d551b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d551b_level0_col0" class="col_heading level0 col0" >n_title</th>
#       <th id="T_d551b_level0_col1" class="col_heading level0 col1" >n_link</th>
#       <th id="T_d551b_level0_col2" class="col_heading level0 col2" >n_date_published</th>
#       <th id="T_d551b_level0_col3" class="col_heading level0 col3" >n_summary</th>
#       <th id="T_d551b_level0_col4" class="col_heading level0 col4" >token count</th>
#       <th id="T_d551b_level0_col5" class="col_heading level0 col5" >similarity score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d551b_level0_row0" class="row_heading level0 row0" >1034</th>
# ...

# %%
response = run("How much is Exxon planning to invest in Hydrogen?", 5, df['embeddings'], df)

response.style.set_properties(subset=['n_summary'], **{'width': '900px'})
# Out:
# <style type="text/css">
# #T_35c86_row0_col3, #T_35c86_row1_col3, #T_35c86_row2_col3, #T_35c86_row3_col3, #T_35c86_row4_col3 {
#   width: 900px;
# }
# </style>
# <table id="T_35c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35c86_level0_col0" class="col_heading level0 col0" >n_title</th>
#       <th id="T_35c86_level0_col1" class="col_heading level0 col1" >n_link</th>
#       <th id="T_35c86_level0_col2" class="col_heading level0 col2" >n_date_published</th>
#       <th id="T_35c86_level0_col3" class="col_heading level0 col3" >n_summary</th>
#       <th id="T_35c86_level0_col4" class="col_heading level0 col4" >token count</th>
#       <th id="T_35c86_level0_col5" class="col_heading level0 col5" >similarity score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35c86_level0_row0" class="row_heading level0 row0" >200</th>
# ...

# %% [markdown]
# ## Output Data (if needed)

# %%
"""

del df['similarity score']

OUTPUT_filepath = "C:\\Users\\hlmq\\OneDrive - Chevron\\Desktop\\Projects\\Company Relationships\\Data\\Exxon\\"
OUTPUT_file = "CompanyProfileNewsData_withEmbeddings.json"

df.to_json(str(OUTPUT_filepath)+str(OUTPUT_file), orient='records')

"""
# Out:
# '\n\ndel df[\'similarity score\']\n\nOUTPUT_filepath = "C:\\Users\\hlmq\\OneDrive - Chevron\\Desktop\\Projects\\Company Relationships\\Data\\Exxon\\"\nOUTPUT_file = "CompanyProfileNewsData_withEmbeddings.json"\n\ndf.to_json(str(OUTPUT_filepath)+str(OUTPUT_file), orient=\'records\')\n\n'
